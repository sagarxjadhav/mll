# %%
import pandas as pd

# %%
df=pd.read_csv('second_data.csv')

# %%
df.head()
# Out:
#    TransactionNo          Items             DateTime  Daypart  DayType
# 0              1          Bread  2016-10-30 09:58:11  Morning  Weekend
# 1              2   Scandinavian  2016-10-30 10:05:34  Morning  Weekend
# 2              2   Scandinavian  2016-10-30 10:05:34  Morning  Weekend
# 3              3  Hot chocolate  2016-10-30 10:07:57  Morning  Weekend
# 4              3            Jam  2016-10-30 10:07:57  Morning  Weekend

# %%
df.tail()
# Out:
#        TransactionNo      Items             DateTime    Daypart  DayType
# 20502           9682     Coffee  2017-09-04 14:32:58  Afternoon  Weekend
# 20503           9682        Tea  2017-09-04 14:32:58  Afternoon  Weekend
# 20504           9683     Coffee  2017-09-04 14:57:06  Afternoon  Weekend
# 20505           9683     Pastry  2017-09-04 14:57:06  Afternoon  Weekend
# 20506           9684  Smoothies  2017-09-04 15:04:24  Afternoon  Weekend

# %%
df.dtypes
# Out:
# TransactionNo     int64
# Items            object
# DateTime         object
# Daypart          object
# DayType          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20507 entries, 0 to 20506
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionNo  20507 non-null  int64
#  1   Items          20507 non-null  object
#  2   DateTime       20507 non-null  object
#  3   Daypart        20507 non-null  object
#  4   DayType        20507 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 801.2+ KB

# %%
df.head()
# Out:
#    TransactionNo          Items             DateTime  Daypart  DayType
# 0              1          Bread  2016-10-30 09:58:11  Morning  Weekend
# 1              2   Scandinavian  2016-10-30 10:05:34  Morning  Weekend
# 2              2   Scandinavian  2016-10-30 10:05:34  Morning  Weekend
# 3              3  Hot chocolate  2016-10-30 10:07:57  Morning  Weekend
# 4              3            Jam  2016-10-30 10:07:57  Morning  Weekend

# %%
product=[]
for a,b in df.groupby('TransactionNo').Items:
    r=[]
    for i in b.values:
        r.append(i)
    product.append(r)

# %%
product
# Out:
# [['Bread'],
#  ['Scandinavian', 'Scandinavian'],
#  ['Hot chocolate', 'Jam', 'Cookies'],
#  ['Muffin'],
#  ['Coffee', 'Pastry', 'Bread'],
#  ['Medialuna', 'Pastry', 'Muffin'],
#  ['Medialuna', 'Pastry', 'Coffee', 'Tea'],
#  ['Pastry', 'Bread'],
#  ['Bread', 'Muffin'],
#  ['Scandinavian', 'Medialuna'],
#  ['Bread', 'Medialuna', 'Bread'],
#  ['Jam', 'Coffee', 'Tartine', 'Pastry', 'Tea'],
#  ['Basket', 'Bread', 'Coffee'],
#  ['Bread', 'Medialuna', 'Pastry'],
#  ['Mineral water', 'Scandinavian'],
#  ['Bread', 'Medialuna', 'Coffee'],
#  ['Hot chocolate'],
#  ['Farm House'],
#  ['Farm House', 'Bread'],
#  ['Bread', 'Medialuna'],
#  ['Coffee', 'Coffee', 'Medialuna', 'Bread'],
#  ['Jam'],
#  ['Scandinavian', 'Muffin'],
#  ['Bread'],
#  ['Scandinavian'],
#  ['Fudge'],
#  ['Scandinavian'],
#  ['Coffee', 'Bread'],
#  ['Bread', 'Jam'],
#  ['Bread'],
#  ['Basket'],
#  ['Scandinavian', 'Muffin'],
#  ['Coffee'],
#  ['Coffee', 'Muffin'],
#  ['Muffin', 'Scandinavian'],
#  ['Tea', 'Bread'],
# ...

# %%
product[2]
# Out:
# ['Hot chocolate', 'Jam', 'Cookies']

# %%
3*7/len(df)
# Out:
# 0.0010240405715121665

# %%
from apyori import apriori

# %%
rule=apriori(product,min_support=0.0010,min_confidence=0.13,min_lift=3,max_length=2)

# %%
result=list(rule)

# %%
result
# Out:
# [RelationRecord(items=frozenset({'Juice', 'Chicken Stew'}), support=0.0016904384574749076, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chicken Stew'}), items_add=frozenset({'Juice'}), confidence=0.13008130081300814, lift=3.3732041430003346)]),
#  RelationRecord(items=frozenset({'Sandwich', 'Coke'}), support=0.005176967776016905, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Coke'}), items_add=frozenset({'Sandwich'}), confidence=0.266304347826087, lift=3.706721547314578)]),
#  RelationRecord(items=frozenset({'Salad', 'Extra Salami or Feta'}), support=0.0016904384574749076, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Extra Salami or Feta'}), items_add=frozenset({'Salad'}), confidence=0.42105263157894735, lift=40.25518341307814), OrderedStatistic(items_base=frozenset({'Salad'}), items_add=frozenset({'Extra Salami or Feta'}), confidence=0.16161616161616163, lift=40.25518341307815)]),
# ...

# %%
result[0]
# Out:
# RelationRecord(items=frozenset({'Juice', 'Chicken Stew'}), support=0.0016904384574749076, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chicken Stew'}), items_add=frozenset({'Juice'}), confidence=0.13008130081300814, lift=3.3732041430003346)])

# %%
result[0][0]
# Out:
# frozenset({'Chicken Stew', 'Juice'})
